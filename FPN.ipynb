# %%
import segmentation_models as sm

BACKBONE = 'resnet50'
preprocess_input = sm.get_preprocessing(BACKBONE)

# load your data
#x_train, y_train, x_val, y_val = load_data(...)

# preprocess input
#x_train = preprocess_input(x_train)
#x_val = preprocess_input(x_val)

# define model
model = sm.FPN(BACKBONE, classes=1, activation='sigmoid', encoder_weights='imagenet')
model.compile(
    'Adam',
    loss=sm.losses.bce_jaccard_loss,
    metrics=[sm.metrics.iou_score],
)

# fit model
# if you use data generator use model.fit_generator(...) instead of model.fit(...)
# more about `fit_generator` here: https://keras.io/models/sequential/#fit_generator

# %%
#!pip install efficientnet
#!pip install classification-models-keras
#!pip install classification-models
#!pip install segmentation-models

# %%
#import segmentation_models as sm

#model = sm.Unet('resnet34', classes=1, activation='sigmoid')

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

#New generator with rotation and shear where interpolation that comes with rotation and shear are thresholded in masks.
#This gives a binary mask rather than a mask with interpolated values.
seed=24
batch_size= 8
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#####################################################################
#Define the model. Experiment with various loss functions and accuracy metrics
# pip install focal-loss

#######################################


#Jaccard distance loss mimics IoU.
#from keras import backend as K
import tensorflow.keras.backend as K
def jaccard_distance_loss(y_true, y_pred, smooth=100):
    """
    Jaccard = (|X & Y|)/ (|X|+ |Y| - |X & Y|)
            = sum(|A*B|)/(sum(|A|)+sum(|B|)-sum(|A*B|))

    The jaccard distance loss is usefull for unbalanced datasets. This has been
    shifted so it converges on 0 and is smoothed to avoid exploding or disapearing
    gradient.

    Ref: https://en.wikipedia.org/wiki/Jaccard_index

    @url: https://gist.github.com/wassname/f1452b748efcbeb4cb9b1d059dce6f96
    @author: wassname
    """
    intersection = K.sum(K.sum(K.abs(y_true * y_pred), axis=-1))
    sum_ = K.sum(K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1))
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac) * smooth

#Dice metric can be a great metric to track accuracy of semantic segmentation.
def dice_metric(y_pred, y_true):
    intersection = K.sum(K.sum(K.abs(y_true * y_pred), axis=-1))
    union = K.sum(K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1))
    # if y_pred.sum() == 0 and y_pred.sum() == 0:
    #     return 1.0

    return 2*intersection / union

# %%
import os
#os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input

from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D, UpSampling2D, Reshape, Dense

from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50
import tensorflow as tf

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import UpSampling2D, Conv2D, Activation, BatchNormalization, Concatenate, AveragePooling2D
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import ResNet50
import keras
img_size = (224, 224)
num_classes = 1

# %%
import os
#os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
#from metrics import dice_loss, dice_coef, iou

# %%
metrics = ["accuracy",
           tf.keras.metrics.AUC(),
           tf.keras.metrics.SensitivityAtSpecificity(0.5),
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
          dice_metric,
          jaccard_distance_loss]
model.compile(loss="binary_crossentropy", optimizer=Adam(1e-4), metrics=metrics)

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
   tf.keras.callbacks.ModelCheckpoint(
    'wholemodel.keras',
    monitor='val_loss',
    verbose=0,
    save_best_only=False,
    #save_weights_only=False,
    mode='auto',
    save_freq='epoch',
    initial_value_threshold=None
),
    CSVLogger("dataResUnet.csv"),
    TensorBoard(log_dir='./logs')
]

# %%
import os
batch_size=8

num_train_imgs = len(os.listdir("C:\\recent caltech\\journal 2 GA for segmentation\\original split\\all images\\train images\\train"))

steps_per_epoch1 = num_train_imgs //batch_size
print(steps_per_epoch1)

num_train_imgs1 = len(os.listdir("C:\\recent caltech\\journal 2 GA for segmentation\\original split\\output splitted\\val\\images"))

steps_per_epoch2 = num_train_imgs1 //batch_size
print(steps_per_epoch2)
# Out:
# 749
# 362

# %%
img_height,img_width=224,224
#from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator


input_imgen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   rotation_range=5.,
                                   horizontal_flip = True)

test_imgen = ImageDataGenerator(rescale = 1./255)



def generate_generator_multiple(generator,dir1, dir4,color_mode, batch_size, img_height,img_width):
    genX1 = generator.flow_from_directory(dir1,
                                          target_size = (img_height,img_width),
                                          class_mode = None,
                                          batch_size = batch_size,
                                          shuffle=False,
                                          seed=7)

    genY1 = generator.flow_from_directory(dir4,
                                          target_size = (img_height,img_width),
                                          class_mode = None,
                                          batch_size = batch_size,
                                          color_mode='grayscale',
                                          shuffle=False,
                                          seed=7)
    while True:
            X1i = genX1.__next__()

            XYi = genY1.__next__()
            yield X1i, XYi  #Yield both images and their mutual label

def generate_generator_testing(generator,dir1,color_mode, batch_size, img_height,img_width):
    genX1 = generator.flow_from_directory(dir1,
                                          target_size = (img_height,img_width),
                                          class_mode = None,
                                          batch_size = batch_size,
                                          shuffle=False,
                                          seed=7)



    while True:
            X1i = genX1.__next__()
            #XYi = genY1.next()
            yield X1i  #Yield both images and their mutual label

# %%
batch_size=8
img_height=224
img_width=224

inputgenerator=generate_generator_multiple(generator=input_imgen,
                                           dir1="C:\\recent caltech\\journal 2 GA for segmentation\\original split\\all images\\train images",
                                           
                                           dir4="C:\\recent caltech\\journal 2 GA for segmentation\\original split\\all masks\\train masks",
                                           
                                           batch_size=batch_size,
                                           img_height=img_height,
                                           color_mode='grayscale',
                                           img_width=img_width)       
     
valgenerator=generate_generator_multiple(generator=test_imgen,
                                          dir1="C:\\recent caltech\\journal 2 GA for segmentation\\original split\\output splitted\\test\\images\\",
                                        
                                          dir4="C:\\recent caltech\\journal 2 GA for segmentation\\original split\\output splitted\\test\\masks\\",
                                          batch_size=batch_size,
                                          color_mode='grayscale',
                                          img_height=img_height,
                                          img_width=img_width)

# %%
callbacks = [EarlyStopping(monitor='val_loss' , patience=5 , restore_best_weights=True)]

# %%
results=model.fit(inputgenerator,
                        steps_per_epoch=steps_per_epoch1,
                        epochs =20,
                        validation_data = valgenerator,
                        validation_steps = steps_per_epoch2,
                        callbacks=callbacks ,
                        #use_multiprocessing=True,
                        #shuffle=False
                           )
# Out:
# Found 5994 images belonging to 1 classes.
# Found 5994 images belonging to 1 classes.
# Epoch 1/20
# 749/749 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9053 - auc_1: 0.9597 - sensitivity_at_specificity_1: 0.9858 - specificity_at_sensitivity_1: 0.9970 - dice_metric: 0.7353 - jaccard_distance_loss: 40.9690Found 2897 images belonging to 1 classes.
# Found 2897 images belonging to 1 classes.
# 749/749 [==============================] - 209s 267ms/step - loss: 0.1363 - accuracy: 0.9053 - auc_1: 0.9597 - sensitivity_at_specificity_1: 0.9858 - specificity_at_sensitivity_1: 0.9970 - dice_metric: 0.7353 - jaccard_distance_loss: 40.9690 - val_loss: 0.1133 - val_accuracy: 0.9202 - val_auc_1: 0.9732 - val_sensitivity_at_specificity_1: 0.9880 - val_specificity_at_sensitivity_1: 0.9991 - val_dice_metric: 0.7325 - val_jaccard_distance_loss: 41.7728
# Epoch 2/20
# 749/749 [==============================] - 199s 266ms/step - loss: 0.0818 - accuracy: 0.9209 - auc_1: 0.9805 - sensitivity_at_specificity_1: 0.9855 - specificity_at_sensitivity_1: 0.9998 - dice_metric: 0.8271 - jaccard_distance_loss: 29.3028 - val_loss: 0.0756 - val_accuracy: 0.9345 - val_auc_1: 0.9823 - val_sensitivity_at_specificity_1: 0.9842 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8303 - val_jaccard_distance_loss: 28.8463
# Epoch 3/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0756 - accuracy: 0.9226 - auc_1: 0.9823 - sensitivity_at_specificity_1: 0.9851 - specificity_at_sensitivity_1: 0.9999 - dice_metric: 0.8409 - jaccard_distance_loss: 27.2885 - val_loss: 0.0849 - val_accuracy: 0.9306 - val_auc_1: 0.9844 - val_sensitivity_at_specificity_1: 0.9916 - val_specificity_at_sensitivity_1: 0.9998 - val_dice_metric: 0.8302 - val_jaccard_distance_loss: 28.8318
# Epoch 4/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0730 - accuracy: 0.9233 - auc_1: 0.9833 - sensitivity_at_specificity_1: 0.9854 - specificity_at_sensitivity_1: 0.9999 - dice_metric: 0.8467 - jaccard_distance_loss: 26.4256 - val_loss: 0.0751 - val_accuracy: 0.9347 - val_auc_1: 0.9825 - val_sensitivity_at_specificity_1: 0.9861 - val_specificity_at_sensitivity_1: 0.9998 - val_dice_metric: 0.8275 - val_jaccard_distance_loss: 29.2326
# Epoch 5/20
# 749/749 [==============================] - 198s 264ms/step - loss: 0.0708 - accuracy: 0.9238 - auc_1: 0.9841 - sensitivity_at_specificity_1: 0.9855 - specificity_at_sensitivity_1: 0.9999 - dice_metric: 0.8524 - jaccard_distance_loss: 25.5723 - val_loss: 0.0781 - val_accuracy: 0.9335 - val_auc_1: 0.9814 - val_sensitivity_at_specificity_1: 0.9888 - val_specificity_at_sensitivity_1: 0.9996 - val_dice_metric: 0.8175 - val_jaccard_distance_loss: 30.6520
# Epoch 6/20
# 749/749 [==============================] - 199s 265ms/step - loss: 0.0675 - accuracy: 0.9245 - auc_1: 0.9855 - sensitivity_at_specificity_1: 0.9866 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8587 - jaccard_distance_loss: 24.6119 - val_loss: 0.0708 - val_accuracy: 0.9365 - val_auc_1: 0.9830 - val_sensitivity_at_specificity_1: 0.9831 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8371 - val_jaccard_distance_loss: 27.8634
# Epoch 7/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0671 - accuracy: 0.9246 - auc_1: 0.9857 - sensitivity_at_specificity_1: 0.9863 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8602 - jaccard_distance_loss: 24.3758 - val_loss: 0.0825 - val_accuracy: 0.9327 - val_auc_1: 0.9783 - val_sensitivity_at_specificity_1: 0.9795 - val_specificity_at_sensitivity_1: 0.9998 - val_dice_metric: 0.8397 - val_jaccard_distance_loss: 27.4397
# Epoch 8/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0676 - accuracy: 0.9247 - auc_1: 0.9855 - sensitivity_at_specificity_1: 0.9865 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8588 - jaccard_distance_loss: 24.6042 - val_loss: 0.0672 - val_accuracy: 0.9373 - val_auc_1: 0.9842 - val_sensitivity_at_specificity_1: 0.9849 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8477 - val_jaccard_distance_loss: 26.2889
# Epoch 9/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0628 - accuracy: 0.9261 - auc_1: 0.9873 - sensitivity_at_specificity_1: 0.9873 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8681 - jaccard_distance_loss: 23.1771 - val_loss: 0.0672 - val_accuracy: 0.9373 - val_auc_1: 0.9836 - val_sensitivity_at_specificity_1: 0.9817 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8566 - val_jaccard_distance_loss: 24.9336
# Epoch 10/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0644 - accuracy: 0.9251 - auc_1: 0.9870 - sensitivity_at_specificity_1: 0.9874 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8654 - jaccard_distance_loss: 23.5823 - val_loss: 0.0682 - val_accuracy: 0.9370 - val_auc_1: 0.9828 - val_sensitivity_at_specificity_1: 0.9805 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8516 - val_jaccard_distance_loss: 25.6884
# Epoch 11/20
# 749/749 [==============================] - 199s 265ms/step - loss: 0.0633 - accuracy: 0.9254 - auc_1: 0.9874 - sensitivity_at_specificity_1: 0.9879 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8676 - jaccard_distance_loss: 23.2420 - val_loss: 0.0685 - val_accuracy: 0.9372 - val_auc_1: 0.9812 - val_sensitivity_at_specificity_1: 0.9752 - val_specificity_at_sensitivity_1: 0.9998 - val_dice_metric: 0.8584 - val_jaccard_distance_loss: 24.6543
# Epoch 12/20
# 749/749 [==============================] - 198s 264ms/step - loss: 0.0629 - accuracy: 0.9257 - auc_1: 0.9878 - sensitivity_at_specificity_1: 0.9884 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8680 - jaccard_distance_loss: 23.1895 - val_loss: 0.0675 - val_accuracy: 0.9374 - val_auc_1: 0.9828 - val_sensitivity_at_specificity_1: 0.9797 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8540 - val_jaccard_distance_loss: 25.3370
# Epoch 13/20
# 749/749 [==============================] - 198s 264ms/step - loss: 0.0635 - accuracy: 0.9253 - auc_1: 0.9878 - sensitivity_at_specificity_1: 0.9886 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8663 - jaccard_distance_loss: 23.4441 - val_loss: 0.0675 - val_accuracy: 0.9376 - val_auc_1: 0.9829 - val_sensitivity_at_specificity_1: 0.9800 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8616 - val_jaccard_distance_loss: 24.1710
# Epoch 14/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0608 - accuracy: 0.9262 - auc_1: 0.9884 - sensitivity_at_specificity_1: 0.9888 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8718 - jaccard_distance_loss: 22.5971 - val_loss: 0.0668 - val_accuracy: 0.9377 - val_auc_1: 0.9836 - val_sensitivity_at_specificity_1: 0.9817 - val_specificity_at_sensitivity_1: 0.9996 - val_dice_metric: 0.8620 - val_jaccard_distance_loss: 24.0925
# Epoch 15/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0600 - accuracy: 0.9261 - auc_1: 0.9890 - sensitivity_at_specificity_1: 0.9893 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8734 - jaccard_distance_loss: 22.3442 - val_loss: 0.0682 - val_accuracy: 0.9375 - val_auc_1: 0.9822 - val_sensitivity_at_specificity_1: 0.9783 - val_specificity_at_sensitivity_1: 0.9997 - val_dice_metric: 0.8605 - val_jaccard_distance_loss: 24.3212
# Epoch 16/20
# 749/749 [==============================] - 199s 265ms/step - loss: 0.0584 - accuracy: 0.9267 - auc_1: 0.9898 - sensitivity_at_specificity_1: 0.9900 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8752 - jaccard_distance_loss: 22.0452 - val_loss: 0.0667 - val_accuracy: 0.9380 - val_auc_1: 0.9829 - val_sensitivity_at_specificity_1: 0.9796 - val_specificity_at_sensitivity_1: 0.9997 - val_dice_metric: 0.8673 - val_jaccard_distance_loss: 23.2817
# Epoch 17/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0589 - accuracy: 0.9263 - auc_1: 0.9897 - sensitivity_at_specificity_1: 0.9901 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8746 - jaccard_distance_loss: 22.1326 - val_loss: 0.0848 - val_accuracy: 0.9342 - val_auc_1: 0.9774 - val_sensitivity_at_specificity_1: 0.9757 - val_specificity_at_sensitivity_1: 0.9996 - val_dice_metric: 0.8222 - val_jaccard_distance_loss: 29.9926
# Epoch 18/20
# 749/749 [==============================] - 198s 265ms/step - loss: 0.0613 - accuracy: 0.9255 - auc_1: 0.9884 - sensitivity_at_specificity_1: 0.9889 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8698 - jaccard_distance_loss: 22.8853 - val_loss: 0.0686 - val_accuracy: 0.9376 - val_auc_1: 0.9822 - val_sensitivity_at_specificity_1: 0.9782 - val_specificity_at_sensitivity_1: 0.9998 - val_dice_metric: 0.8587 - val_jaccard_distance_loss: 24.5996
# Epoch 19/20
# 749/749 [==============================] - 199s 265ms/step - loss: 0.0571 - accuracy: 0.9268 - auc_1: 0.9906 - sensitivity_at_specificity_1: 0.9910 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8772 - jaccard_distance_loss: 21.7339 - val_loss: 0.0657 - val_accuracy: 0.9383 - val_auc_1: 0.9835 - val_sensitivity_at_specificity_1: 0.9809 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8606 - val_jaccard_distance_loss: 24.3319
# Epoch 20/20
# 749/749 [==============================] - 199s 265ms/step - loss: 0.0557 - accuracy: 0.9271 - auc_1: 0.9913 - sensitivity_at_specificity_1: 0.9917 - specificity_at_sensitivity_1: 1.0000 - dice_metric: 0.8793 - jaccard_distance_loss: 21.4048 - val_loss: 0.0702 - val_accuracy: 0.9381 - val_auc_1: 0.9815 - val_sensitivity_at_specificity_1: 0.9756 - val_specificity_at_sensitivity_1: 0.9999 - val_dice_metric: 0.8497 - val_jaccard_distance_loss: 25.9883

# %%
"""
model.fit(
   x=x_train,
   y=y_train,
   batch_size=16,
   epochs=100,
   validation_data=(x_val, y_val),
)
"""
# Out:
# '\nmodel.fit(\n   x=x_train,\n   y=y_train,\n   batch_size=16,\n   epochs=100,\n   validation_data=(x_val, y_val),\n)\n'

# %%
import pandas as pd
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#         loss  accuracy     auc_1  sensitivity_at_specificity_1  \
# 18  0.057077  0.926844  0.990556                      0.991024
# 15  0.058351  0.926716  0.989787                      0.990043
# 13  0.060797  0.926154  0.988445                      0.988766
# 8   0.062763  0.926137  0.987288                      0.987296
# 7   0.067560  0.924689  0.985481                      0.986536
# 11  0.062892  0.925710  0.987813                      0.988386
# 12  0.063494  0.925271  0.987768                      0.988568
# 9   0.064408  0.925119  0.986988                      0.987446
# 14  0.059974  0.926089  0.988977                      0.989338
# 10  0.063255  0.925444  0.987388                      0.987909
# 17  0.061317  0.925545  0.988391                      0.988920
# 19  0.055684  0.927056  0.991285                      0.991717
# 5   0.067521  0.924547  0.985498                      0.986566
# 3   0.072964  0.923275  0.983346                      0.985422
# 1   0.081850  0.920907  0.980462                      0.985495
# 4   0.070786  0.923760  0.984102                      0.985537
# 6   0.067058  0.924607  0.985670                      0.986343
# 16  0.058941  0.926289  0.989714                      0.990140
# 2   0.075621  0.922644  0.982284                      0.985085
# 0   0.136272  0.905307  0.959693                      0.985764
#
#     specificity_at_sensitivity_1  dice_metric  jaccard_distance_loss  \
# 18                      0.999990     0.877200              21.733864
# 15                      0.999992     0.875248              22.045221
# 13                      0.999987     0.871773              22.597101
# 8                       0.999988     0.868075              23.177069
# 7                       0.999952     0.858780              24.604185
# 11                      0.999958     0.867989              23.189495
# 12                      0.999972     0.866292              23.444084
# 9                       0.999963     0.865439              23.582251
# 14                      0.999985     0.873383              22.344233
# 10                      0.999987     0.867623              23.241961
# 17                      0.999978     0.869787              22.885347
# 19                      0.999997     0.879258              21.404839
# 5                       0.999970     0.858723              24.611870
# 3                       0.999915     0.846685              26.425632
# 1                       0.999777     0.827129              29.302807
# 4                       0.999930     0.852359              25.572285
# 6                       0.999963     0.860213              24.375793
# 16                      0.999979     0.874564              22.132629
# 2                       0.999862     0.840907              27.288549
# 0                       0.996973     0.735292              40.968960
#
#     val_loss  val_accuracy  val_auc_1  val_sensitivity_at_specificity_1  \
# 18  0.065681      0.938253   0.983525                          0.980896
# 15  0.066726      0.937980   0.982910                          0.979638
# 13  0.066832      0.937698   0.983588                          0.981748
# 8   0.067224      0.937313   0.983635                          0.981665
# 7   0.067247      0.937265   0.984233                          0.984934
# 11  0.067502      0.937379   0.982829                          0.979711
# 12  0.067535      0.937591   0.982910                          0.980019
# 9   0.068174      0.936986   0.982795                          0.980477
# 14  0.068236      0.937492   0.982178                          0.978253
# 10  0.068507      0.937231   0.981192                          0.975157
# 17  0.068600      0.937565   0.982230                          0.978216
# 19  0.070164      0.938103   0.981452                          0.975612
# 5   0.070790      0.936464   0.982992                          0.983115
# 3   0.075066      0.934709   0.982458                          0.986053
# 1   0.075582      0.934472   0.982341                          0.984212
# 4   0.078066      0.933486   0.981437                          0.988795
# 6   0.082519      0.932727   0.978341                          0.979481
# 16  0.084762      0.934196   0.977354                          0.975744
# 2   0.084940      0.930572   0.984408                          0.991555
# 0   0.113302      0.920193   0.973183                          0.987985
#
#     val_specificity_at_sensitivity_1  val_dice_metric  \
# 18                          0.999871         0.860621
# 15                          0.999692         0.867329
# 13                          0.999630         0.862029
# 8                           0.999924         0.856587
# 7                           0.999941         0.847658
# 11                          0.999857         0.853955
# 12                          0.999933         0.861620
# 9                           0.999864         0.851559
# 14                          0.999719         0.860537
# 10                          0.999814         0.858401
# 17                          0.999811         0.858738
# 19                          0.999894         0.849659
# 5                           0.999883         0.837113
# 3                           0.999813         0.827505
# 1                           0.999887         0.830276
# 4                           0.999595         0.817529
# 6                           0.999826         0.839704
# 16                          0.999618         0.822210
# 2                           0.999841         0.830194
# 0                           0.999119         0.732466
#
#     val_jaccard_distance_loss
# 18                  24.331863
# 15                  23.281736
# 13                  24.092495
# 8                   24.933647
# 7                   26.288860
# 11                  25.337009
# 12                  24.171003
# 9                   25.688442
# 14                  24.321209
# 10                  24.654308
# 17                  24.599588
# 19                  25.988302
# 5                   27.863354
# 3                   29.232584
# 1                   28.846327
# 4                   30.652010
# 6                   27.439686
# 16                  29.992584
# 2                   28.831808
# 0                   41.772789

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %%
model.save('FPN2.h5')

# %%
import keras

model = keras.models.load_model('C:\\recent caltech\\journal 2 GA for segmentation\\original split\\FPN2.h5', compile = False)
#model = keras.models.load_model('\\model.h5', compile = False)

METRICS =  ["accuracy",
           tf.keras.metrics.AUC(),
           tf.keras.metrics.SensitivityAtSpecificity(0.5),
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
          dice_metric,
          jaccard_distance_loss]

model.compile(optimizer = keras.optimizers.Adam(learning_rate=1e-4),
              loss = 'binary_crossentropy',
              metrics = METRICS
             )

# %%
"""def generate_generator_multiple(generator,dir1, dir4,color_mode, batch_size, img_height,img_width):
    genX1 = generator.flow_from_directory(dir1,
                                          target_size = (img_height,img_width),
                                          class_mode = None,
                                          batch_size = batch_size,
                                          shuffle=False, 
                                          seed=7)
   
    genY1 = generator.flow_from_directory(dir4,
                                          target_size = (img_height,img_width),
                                          class_mode = None,
                                          batch_size = batch_size,
                                          color_mode='grayscale',
                                          shuffle=False, 
                                          seed=7)
    while True:
            X1i = genX1.next()
            
            XYi = genY1.next()
            yield X1i, XYi 

def generate_generator_testing(generator,dir1,color_mode, batch_size, img_height,img_width):
    genX1 = generator.flow_from_directory(dir1,
                                          target_size = (img_height,img_width),
                                          class_mode = None,
                                          batch_size = batch_size,
                                          shuffle=False, 
                                          seed=7)
    
   
    
    while True:
            X1i = genX1.next()
            #XYi = genY1.next()
            yield X1i  
"""
# Out:
# "def generate_generator_multiple(generator,dir1, dir4,color_mode, batch_size, img_height,img_width):\n    genX1 = generator.flow_from_directory(dir1,\n                                          target_size = (img_height,img_width),\n                                          class_mode = None,\n                                          batch_size = batch_size,\n                                          shuffle=False, \n                                          seed=7)\n   \n    genY1 = generator.flow_from_directory(dir4,\n                                          target_size = (img_height,img_width),\n                                          class_mode = None,\n                                          batch_size = batch_size,\n                                          color_mode='grayscale',\n                                          shuffle=False, \n                                          seed=7)\n    while True:\n            X1i = genX1.next()\n            \n            XYi = genY1.next()\n            yield X1i, XYi \n\ndef generate_generator_testing(generator,dir1,color_mode, batch_size, img_height,img_width):\n    genX1 = generator.flow_from_directory(dir1,\n                                          target_size = (img_height,img_width),\n                                          class_mode = None,\n                                          batch_size = batch_size,\n                                          shuffle=False, \n                                          seed=7)\n    \n   \n    \n    while True:\n            X1i = genX1.next()\n            #XYi = genY1.next()\n            yield X1i  \n"

# %%
import cv2
img_height,img_width=224,224
generator = ImageDataGenerator(rescale = 1./255)

#dir1="C:\\recent caltech\\journal 2 GA for segmentation\\new dataset images\\Woodpeckers bird-20240902T214132Z-001\\"
dir1="C:\\recent caltech\\journal 2 GA for segmentation\\original split\\test"

genX1 = generator.flow_from_directory(dir1,
                                          target_size = (img_height,img_width),
                                          class_mode = None,
                                          batch_size =1,
                                          shuffle=False, 
                                          seed=seed)
for i in range(100):
    #img, label = dir_It.next()
    img1=genX1.next()
    print(img1.shape)   #  (1,256,256,3)
    output_image= model.predict(img1) 
    #generated_image=predict[0]
    #plt.imshow(x)
    #plt.savefig('C:\\recent caltech\\deeplab3++\\raw mobilenet\\oneshot mobilenet masks\\'+str(i)+'.png')
    #plt.imshow(img1[0])
    #generated_image = (generated_image * 255).astype(np.uint8)

    output_image = np.squeeze(output_image)  # Remove batch dimension if necessary

    # Ensure pixel values are in the correct range (0-255 for uint8)
    output_image = (output_image * 255).astype(np.uint8)

    # Save the image
    cv2.imwrite('C:\\recent caltech\\journal 2 GA for segmentation\\original split\\FPN\\'+str(i)+'.png', output_image)
"""
for i in range(100):
    #img, label = dir_It.next()
    img1=genX1.next()
    print(img1.shape)   #  (1,256,256,3)
    predict = model.predict(img1) 
    x=predict[0]
    plt.imshow(x)
    plt.savefig('C:\\recent caltech\\journal 2 GA for segmentation\\new dataset images\\fcn32\\'+str(i)+'.png')
    #plt.savefig('C:\\recent caltech\\journal 2 GA for segmentation\\produced_images\\predicted_fcn32\\'+str(i)+'.png')
    plt.imshow(img1[0])
    #plt.savefig('C:\\recent caltech\\journal 2 GA for segmentation\\produced_images\\original\\'+str(i)+'png')
"""
